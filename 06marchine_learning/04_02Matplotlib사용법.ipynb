# %% [markdown]
# # Matplotlib 파이썬에서 그래프를 그릴 때 사용
# * Matplotlib: 기본툴
# * seaborn: Matplotlib을 간단하고 예쁘게
# * plotly: 그래프에 동적 요소 포함
# * koreanize_matplotlib: Matplotlib, seaborn에서 한글 폰트 자동 설정

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import koreanize_matplotlib

# %% [markdown]
# # 간단한 그래프 예제
# * fig=전체 그래프가 그려지는 도화지
# * ax=한 개의 그래프

# %%
fig, ax = plt.subplots() 
ax.plot([1,2,3,4], [1,4,2,3]) 
plt.show()

# %% [markdown]
# # x,y 축이 하나씩 있는 그래프 그리기

# %%
fig, ax = plt.subplots()
plt.show()

# %% [markdown]
# # 2X2 4개 그래프 그리기

# %%
fig, ax = plt.subplots(2,2)
plt.show
print(ax.shape)
print(ax)
# Out:
# (2, 2)
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]

# %% [markdown]
# # 3X2 그래프 만들기

# %%
fig, ax = plt.subplots(3,2)
plt.show
print(ax.shape)
print(ax)
# Out:
# (3, 2)
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]

# %% [markdown]
# # 2X2 그래프에서 왼쪽 행 결합하기
# plt.subplot_mosaic([['left','right_top'],
#                    ['left','right_bottom']])

# %%
fig, ax = plt.subplot_mosaic([['left','right_top'],
                             ['left','right_bottom']])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 2X2 그래프에서 오른쪽 행 결합하기

# %%
fig, ax = plt.subplot_mosaic([['left_1','right'],
                              ['left_2','right']])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 2X2 그래프에서 윗열 결합하기

# %%
fig, ax = plt.subplot_mosaic([['top','top'],
                              ['left_bottom','right_bottom']])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 2X2 그래프에서 아래열 결합하기

# %%
fig, ax = plt.subplot_mosaic([['left_top','right_top'],
                              ['bottom','bottom']])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # matplotlib의 2가지 코딩 스타일

# %% [markdown]
# ## 00-스타일: matplotlib의 공식 추천 스타일
# * 복잡한 그래프를 그릴 때 사용
# * 사용법이 pyplot 스타일보다 복잡함

# %%
x = np.linspace(0,2,100)
x
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
#        1.41414141, 1.43434343, 1.45454545, 1.47474747, 1.49494949,
#        1.51515152, 1.53535354, 1.55555556, 1.57575758, 1.5959596 ,
#        1.61616162, 1.63636364, 1.65656566, 1.67676768, 1.6969697 ,
#        1.71717172, 1.73737374, 1.75757576, 1.77777778, 1.7979798 ,
#        1.81818182, 1.83838384, 1.85858586, 1.87878788, 1.8989899 ,
#        1.91919192, 1.93939394, 1.95959596, 1.97979798, 2.        ])

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(x, x, label='linear')
ax.plot(x, x**2, label='quadratic')
ax.plot(x, x**3, label='cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('간단 그래프')
ax.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots(3,1, figsize=(5, 7))
ax[0].plot(x, x, label='linear')
ax[1].plot(x, x**2, label='quadratic')
ax[2].plot(x, x**3, label='cubic')
ax[0].set_xlabel('x label')
ax[0].set_ylabel('y label')
ax[0].set_title('linear 간단 그래프')
ax[1].set_xlabel('x label')
ax[1].set_ylabel('y label')
ax[1].set_title('quadratic 간단 그래프')
ax[2].set_xlabel('x label')
ax[2].set_ylabel('y label')
ax[2].set_title('cubic 간단 그래프')
plt.tight_layout() #깔끔하게 간격 조정

# %% [markdown]
# ## pyplot 스타일
# * 00-스타일보다 사용법 간단
# * 복잡한 그래프를 그릴 때는 부적합

# %%
plt.figure(figsize=(5, 2.7))
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title('pyplot 간단 그래프')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 선 모양 바꾸기 set_linestyle(모양)

# %%
data1, data2, data3, data4 = np.random.randn(4,100)

# %%
print(data1)
print(data2)
print(data3)
print(data4)
# Out:
# [ 0.11652632  0.91909755  0.62624575  2.07925345 -0.85927859  1.00892474
#  -1.40055731 -0.32436691 -0.66204434 -0.03117258  1.96403585 -2.13682669
#  -0.26619291  0.28545395 -1.38095646 -0.64969106  1.51815372  0.10834503
#  -0.00889553  1.16260575 -0.0390648   0.24118762  0.08800334 -0.97359067
#   0.14925894 -0.49249524 -0.64888392 -1.27001563  0.04589202 -1.07543497
#   0.1293348   0.90216608 -1.71989534  0.28062007 -0.44852532  0.80262008
#   1.26171148 -0.2247558  -0.15528812  1.23504467  0.02318461  0.95538885
#  -0.54392376  1.35311182 -0.65521811  0.5371477  -0.01760965 -0.47867723
#  -0.31659646  1.68393973  0.5502483   0.1344202  -0.46147911  0.19362139
#   1.49692256 -2.10180977  0.04721071  0.77683389 -0.68369342 -3.21160938
#  -0.50061602 -0.51451951 -0.58092596  1.1694416   1.4817436  -0.41641618
#  -1.50012527 -0.16147792  0.79338095 -0.70883946  0.18704563 -2.11586185
#  -2.57529629 -0.61700706 -0.29630918  0.12232905 -1.7977477  -0.67471867
#   1.20959512  0.86449099  1.58227349 -0.67631784 -1.72625827 -0.26939765
#   2.47473165  1.26000278 -1.15036404  0.03977182 -1.53282443  0.77255998
#  -1.7547082   0.90833302 -0.48078953 -0.32952991 -1.20032983 -1.02784365
#   1.98244278  0.00375808 -2.18773085  0.07122329 -0.46259835  0.98657385
#   0.98059962 -1.58115807 -0.77010738  0.076325   -0.48419329 -1.34186068
#   0.61038712  1.26461678  1.50355049 -0.64142242 -0.13101698  0.5027204
#   0.68576485  1.29911892  1.57239225 -0.40312525 -0.59744345 -0.78311552
#   0.40112284  1.29096136 -0.45717455 -0.44337586 -0.92973705  1.77860086
#   0.26946648  0.76898574 -0.6570938   1.563889   -0.22905125 -0.15445553
#  -0.84977483 -0.73489681 -0.8631801  -0.83430877 -0.19778406  1.26075058
#   0.85921506 -2.05240398  0.21354524 -1.05086319 -0.92909227 -0.24098925
#  -1.06292829 -0.96528141  0.14060146  0.95745658]

# %% [markdown]
# 선모양: '-', '--', '-.', ':'

# %%
fig, ax = plt.subplots(figsize=(5,2.7))
x = np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color='blue', linewidth=3, linestyle=":")
ax.plot(x, np.cumsum(data2), color='orange', linewidth=2, linestyle="-.")
plt.show()

# %% [markdown]
# # 산점도 스래프를 그리고 색 변경하기
# * 원 크기: s
# * 안쪽색: c='색상'
# * 테두리색 : face

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1, data2, s=50, c='c', edgecolors='k')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1, data2, s=50, c=(1,0,0), edgecolors='k')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10820\3620338101.py:2: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(data1, data2, s=50, c=(1,0,0), edgecolors='k')

# %% [markdown]
# | 마커 | 설명 |
# |-----|:-----|
# |'.' |        point marker |
# |',' |       pixel marker |
# |'o' |        circle marker|
# |'v' |        triangle_down marker|
# |'^' |        triangle_up marker|
# |'<' |        triangle_left marker|
# |'>' |        triangle_right marker|
# |'1' |        tri_down marker|
# |'2' |        tri_up marker|
# |'3' |        tri_left marker|
# |'4' |        tri_right marker|
# |'8' |        octagon marker|
# |'s' |        square marker|
# |'p' |        pentagon marker|
# |'P' |        plus (filled) marker|
# |'*' |        star marker|
# |'h' |        hexagon1 marker|
# |'H' |        hexagon2 marker|
# |'+' |        plus marker|
# |'x' |        x marker|
# |'X' |        x (filled) marker|
# |'D' |        diamond marker|
# |'d' |        thindiamond marker|
# |'|' |        vline marker|
# |``''`` |        hline marker|

# %%
fig, ax = plt.subplots(figsize=(5, 4))
ax.plot(data1, '8', label=data1)
ax.plot(data2, 'D', label=data2)
ax.plot(data3, '3', label=data3)
ax.plot(data4, 'h', label=data4)
ax.legend()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10820\2443344843.py:2: MatplotlibDeprecationWarning: Passing label as a length 100 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   ax.plot(data1, marker='8', label=data1)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10820\2443344843.py:3: MatplotlibDeprecationWarning: Passing label as a length 100 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   ax.plot(data2, marker='D', label=data2)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10820\2443344843.py:4: MatplotlibDeprecationWarning: Passing label as a length 100 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   ax.plot(data3, marker='3', label=data3)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10820\2443344843.py:5: MatplotlibDeprecationWarning: Passing label as a length 100 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   ax.plot(data4, marker='h', label=data4)

# %% [markdown]
# # X축, Y축 이름, 눈금, 그래프이름

# %%
mu,sigma = 155, 15
x = mu+sigma * np.random.randn(10000)
fig, ax = plt.subplots(figsize=(5,2.7))
n, bins, patches = ax.hist(x, 50, density=True, color='C0', alpha=0.75)
ax.set_xlabel('Length[cm]')
ax.set_ylabel('Probability')
ax.set_title("Aardvark lengths \n (not really)")
ax.text(75,0.025, r'$\mu=115, \ \sigma=15$')
ax.axis([60,160,0,0.03])
# Out:
# (np.float64(60.0), np.float64(160.0), np.float64(0.0), np.float64(0.03))

# %% [markdown]
# # 눈금자 단위 구간 설정하기

# %%
xdata = np.arange(len(data1))
fig, ax = plt.subplots(2, 1, figsize=(5,2.7), layout='constrained')
ax[0].plot(xdata, data1)
ax[0].set_title("automatic ticks")

ax[1].plot(xdata, data2)
ax[1].set_xticks(np.arange(0, 100, 30), ['zero','30','sixty','90'])
ax[1].set_yticks([-1.5, 0, 1.5])
ax[1].set_title("manual ticks")
plt.show()

# %% [markdown]
# # 카테고리 막대 그래프 그리기

# %%
fig, ax = plt.subplots(figsize=(5,2.7))
categories = ['turnips','rutabaga','cucumber','pumpkins']
ax.bar(categories, np.random.rand(len(categories)))
plt.show()
