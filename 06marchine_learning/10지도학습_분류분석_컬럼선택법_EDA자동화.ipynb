# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data = pd.read_csv("./data/salary2.csv")
data.head()
# Out:
#    age   workclass      education  education-num       marital-status  \
# 0   25     Private           11th              7        Never-married
# 1   38     Private        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private   Some-college             10   Married-civ-spouse
# 4   18         NaN   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                 NaN    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country   class
# 0             0              40   United-States   <=50K
# 1             0              50   United-States   <=50K
# 2             0              40   United-States    >50K
# 3             0              40   United-States    >50K
# 4             0              30   United-States   <=50K

# %%
data2 = data.copy()

# %% [markdown]
# # ydata로 EDA하기

# %%
# !pip install ydata-profiling
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipywidgets) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: decorator in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack-data in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.14.1)
# Requirement already satisfied: exceptiongroup in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.3.0)
# Requirement already satisfied: colorama in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
profile = ProfileReport(data, title="Profiling Report") # 분석리포트 만들기
profile.to_notebook_iframe() # 주피터노트북 출력창에 결과 출력
profile.to_file("salary데이터EDA.html") # 분석결과를 html 파일로 출력
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/14 [00:00<?, ?it/s]
#  14%|███████████▊                                                                       | 2/14 [00:01<00:08,  1.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:01<00:00,  8.03it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-11-12 02:31:20.123050&quot; name=date&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# 중복행 제거, 결측값 제거

# %%
data = data.drop_duplicates()

# %%
data = data.dropna()

# %%
data = data.reset_index(drop=True)

# %%
data
# Out:
#        age      workclass      education  education-num       marital-status  \
# 0       25        Private           11th              7        Never-married
# 1       38        Private        HS-grad              9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm             12   Married-civ-spouse
# 3       44        Private   Some-college             10   Married-civ-spouse
# 4       34        Private           10th              6        Never-married
# ...    ...            ...            ...            ...                  ...
# 39235   53        Private        Masters             14   Married-civ-spouse
# 39236   22        Private   Some-college             10        Never-married
# 39237   27        Private     Assoc-acdm             12   Married-civ-spouse
# 39238   58        Private        HS-grad              9              Widowed
# 39239   52   Self-emp-inc        HS-grad              9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capital-gain  \
# 0       Machine-op-inspct       Own-child   Black     Male             0
# 1         Farming-fishing         Husband   White     Male             0
# 2         Protective-serv         Husband   White     Male             0
# 3       Machine-op-inspct         Husband   Black     Male          7688
# 4           Other-service   Not-in-family   White     Male             0
# ...                   ...             ...     ...      ...           ...
# 39235     Exec-managerial         Husband   White     Male             0
# 39236     Protective-serv   Not-in-family   White     Male             0
# 39237        Tech-support            Wife   White   Female             0
# 39238        Adm-clerical       Unmarried   White   Female             0
# 39239     Exec-managerial            Wife   White   Female         15024
#
#        capital-loss  hours-per-week  native-country   class
# 0                 0              40   United-States   <=50K
# 1                 0              50   United-States   <=50K
# 2                 0              40   United-States    >50K
# 3                 0              40   United-States    >50K
# 4                 0              30   United-States   <=50K
# ...             ...             ...             ...     ...
# 39235             0              40   United-States    >50K
# 39236             0              40   United-States   <=50K
# 39237             0              38   United-States   <=50K
# 39238             0              40   United-States   <=50K
# 39239             0              40   United-States    >50K
#
# [39240 rows x 14 columns]

# %%
data['class'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
data['class'] = data['class'].apply(lambda x: 1 if x == ' >50K' else 0)
data['class'].value_counts()
# Out:
# class
# 0    29265
# 1     9975
# Name: count, dtype: int64

# %% [markdown]
# # 중요 컬럼 선택하기
# 1) EDA를 통해서 종속변수(target)과 중요한 관계가 있는 변수들만 선택
# 2) 수치형 변수는 상관분석 결과를 통해, 범주형 변수는 카이제곱 통계량(통계학적 방법)
# 3) 머신러닝 알고리즘을 통한 1차 분석 후 중요하게 사용된 변수만 선택

# %% [markdown]
# # tree 계열 모델의 feature_importance로 선택하기

# %%
X = data.drop('class', axis=1)
y = data['class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=10, stratify=y)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
def ohe_transform(X_train, X_test):
    train_cat_cols = X_train.select_dtypes(include='object')
    train_num_cols = X_train.select_dtypes(exclude='object')
    test_cat_cols = X_test.select_dtypes(include='object')
    test_num_cols = X_test.select_dtypes(exclude='object')
    
    ohe = OneHotEncoder(drop = 'first', sparse_output=False, handle_unknown='ignore')
    ohe.fit(train_cat_cols)
    train_temp = ohe.transform(train_cat_cols)
    test_temp = ohe.transform(test_cat_cols)
    
    ohe_cols_name = ohe.get_feature_names_out(train_cat_cols.columns)
    
    train_temp_df = pd.DataFrame(train_temp, index=train_cat_cols.index, columns=ohe_cols_name)
    test_temp_df = pd.DataFrame(test_temp, index=test_cat_cols.index, columns=ohe_cols_name)
    
    train_result = pd.concat([train_temp_df, train_num_cols], axis=1)
    test_result = pd.concat([test_temp_df, test_num_cols], axis=1)
    return train_result, test_result

# %%
X_train, X_test = ohe_transform(X_train, X_test)
X_test
# Out:
#        workclass_ Local-gov  workclass_ Private  workclass_ Self-emp-inc  \
# 22149                   0.0                 1.0                      0.0
# 21899                   0.0                 1.0                      0.0
# 12634                   0.0                 1.0                      0.0
# 1171                    0.0                 0.0                      0.0
# 4839                    0.0                 1.0                      0.0
# ...                     ...                 ...                      ...
# 25349                   0.0                 0.0                      1.0
# 34503                   0.0                 1.0                      0.0
# 15058                   0.0                 1.0                      0.0
# 28083                   1.0                 0.0                      0.0
# 38462                   0.0                 1.0                      0.0
#
#        workclass_ Self-emp-not-inc  workclass_ State-gov  \
# 22149                          0.0                   0.0
# 21899                          0.0                   0.0
# 12634                          0.0                   0.0
# 1171                           1.0                   0.0
# 4839                           0.0                   0.0
# ...                            ...                   ...
# 25349                          0.0                   0.0
# 34503                          0.0                   0.0
# 15058                          0.0                   0.0
# 28083                          0.0                   0.0
# 38462                          0.0                   0.0
#
#        workclass_ Without-pay  education_ 11th  education_ 12th  \
# 22149                     0.0              0.0              0.0
# 21899                     0.0              0.0              0.0
# 12634                     0.0              0.0              0.0
# 1171                      0.0              0.0              0.0
# 4839                      0.0              0.0              0.0
# ...                       ...              ...              ...
# 25349                     0.0              0.0              0.0
# 34503                     0.0              0.0              0.0
# 15058                     0.0              0.0              0.0
# 28083                     0.0              0.0              0.0
# 38462                     0.0              0.0              0.0
#
#        education_ 1st-4th  education_ 5th-6th  ...  native-country_ Thailand  \
# 22149                 0.0                 0.0  ...                       0.0
# 21899                 0.0                 0.0  ...                       0.0
# 12634                 0.0                 0.0  ...                       0.0
# 1171                  0.0                 0.0  ...                       0.0
# 4839                  0.0                 0.0  ...                       0.0
# ...                   ...                 ...  ...                       ...
# 25349                 0.0                 0.0  ...                       0.0
# 34503                 0.0                 0.0  ...                       0.0
# 15058                 0.0                 0.0  ...                       0.0
# 28083                 0.0                 0.0  ...                       0.0
# 38462                 0.0                 0.0  ...                       0.0
#
#        native-country_ Trinadad&Tobago  native-country_ United-States  \
# 22149                              0.0                            1.0
# 21899                              0.0                            1.0
# 12634                              0.0                            1.0
# 1171                               0.0                            1.0
# 4839                               0.0                            1.0
# ...                                ...                            ...
# 25349                              0.0                            0.0
# 34503                              0.0                            1.0
# 15058                              0.0                            1.0
# 28083                              0.0                            1.0
# 38462                              0.0                            1.0
#
#        native-country_ Vietnam  native-country_ Yugoslavia  age  \
# 22149                      0.0                         0.0   26
# 21899                      0.0                         0.0   33
# 12634                      0.0                         0.0   41
# 1171                       0.0                         0.0   42
# 4839                       0.0                         0.0   24
# ...                        ...                         ...  ...
# 25349                      0.0                         0.0   50
# 34503                      0.0                         0.0   64
# 15058                      0.0                         0.0   35
# 28083                      0.0                         0.0   27
# 38462                      0.0                         0.0   27
#
#        education-num  capital-gain  capital-loss  hours-per-week
# 22149              9             0             0              40
# 21899             16             0             0              40
# 12634             10             0             0              50
# 1171              10             0             0              70
# 4839               5             0             0              48
# ...              ...           ...           ...             ...
# 25349             15             0             0              40
# 34503             16             0             0              80
# 15058              9             0             0              50
# 28083              6             0             0              60
# 38462              9             0             0              50
#
# [15696 rows x 95 columns]

# %% [markdown]
# # 의사결정나무로 1회 분석 후 컬럼 선별하기

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %%
dtc = DecisionTreeClassifier(max_depth=4, random_state=10)
dtc.fit(X_train, y_train)
pred = dtc.predict(X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89     11706
#            1       0.75      0.51      0.61      3990
#
#     accuracy                           0.83     15696
#    macro avg       0.80      0.73      0.75     15696
# weighted avg       0.83      0.83      0.82     15696

# %%
dtc.feature_importances_
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.88789042e-01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.62473567e-04, 2.24867290e-01,
#        2.52757492e-01, 2.48271326e-02, 8.29657036e-03])

# %%
dtc.feature_names_in_
# Out:
# array(['workclass_ Local-gov', 'workclass_ Private',
#        'workclass_ Self-emp-inc', 'workclass_ Self-emp-not-inc',
#        'workclass_ State-gov', 'workclass_ Without-pay',
#        'education_ 11th', 'education_ 12th', 'education_ 1st-4th',
#        'education_ 5th-6th', 'education_ 7th-8th', 'education_ 9th',
#        'education_ Assoc-acdm', 'education_ Assoc-voc',
#        'education_ Bachelors', 'education_ Doctorate',
#        'education_ HS-grad', 'education_ Masters', 'education_ Preschool',
#        'education_ Prof-school', 'education_ Some-college',
#        'marital-status_ Married-AF-spouse',
#        'marital-status_ Married-civ-spouse',
#        'marital-status_ Married-spouse-absent',
#        'marital-status_ Never-married', 'marital-status_ Separated',
#        'marital-status_ Widowed', 'occupation_ Armed-Forces',
#        'occupation_ Craft-repair', 'occupation_ Exec-managerial',
#        'occupation_ Farming-fishing', 'occupation_ Handlers-cleaners',
#        'occupation_ Machine-op-inspct', 'occupation_ Other-service',
#        'occupation_ Priv-house-serv', 'occupation_ Prof-specialty',
#        'occupation_ Protective-serv', 'occupation_ Sales',
#        'occupation_ Tech-support', 'occupation_ Transport-moving',
#        'relationship_ Not-in-family', 'relationship_ Other-relative',
#        'relationship_ Own-child', 'relationship_ Unmarried',
#        'relationship_ Wife', 'race_ Asian-Pac-Islander', 'race_ Black',
#        'race_ Other', 'race_ White', 'sex_ Male',
#        'native-country_ Canada', 'native-country_ China',
#        'native-country_ Columbia', 'native-country_ Cuba',
#        'native-country_ Dominican-Republic', 'native-country_ Ecuador',
#        'native-country_ El-Salvador', 'native-country_ England',
#        'native-country_ France', 'native-country_ Germany',
#        'native-country_ Greece', 'native-country_ Guatemala',
#        'native-country_ Haiti', 'native-country_ Holand-Netherlands',
#        'native-country_ Honduras', 'native-country_ Hong',
#        'native-country_ Hungary', 'native-country_ India',
#        'native-country_ Iran', 'native-country_ Ireland',
#        'native-country_ Italy', 'native-country_ Jamaica',
#        'native-country_ Japan', 'native-country_ Laos',
#        'native-country_ Mexico', 'native-country_ Nicaragua',
#        'native-country_ Outlying-US(Guam-USVI-etc)',
#        'native-country_ Peru', 'native-country_ Philippines',
#        'native-country_ Poland', 'native-country_ Portugal',
#        'native-country_ Puerto-Rico', 'native-country_ Scotland',
#        'native-country_ South', 'native-country_ Taiwan',
#        'native-country_ Thailand', 'native-country_ Trinadad&Tobago',
#        'native-country_ United-States', 'native-country_ Vietnam',
#        'native-country_ Yugoslavia', 'age', 'education-num',
#        'capital-gain', 'capital-loss', 'hours-per-week'], dtype=object)

# %%
feature_importances = pd.DataFrame(dtc.feature_importances_, index=dtc.feature_names_in_, columns=['importances'])

# %%
feature_importances = feature_importances.sort_values(by='importances', ascending=False)
feature_importances
# Out:
#                                     importances
# marital-status_ Married-civ-spouse     0.488789
# capital-gain                           0.252757
# education-num                          0.224867
# capital-loss                           0.024827
# hours-per-week                         0.008297
# ...                                         ...
# native-country_ South                  0.000000
# native-country_ Scotland               0.000000
# native-country_ Yugoslavia             0.000000
# native-country_ United-States          0.000000
# native-country_ Vietnam                0.000000
#
# [95 rows x 1 columns]

# %%
feature_importances[feature_importances['importances'] > 0]
# Out:
#                                     importances
# marital-status_ Married-civ-spouse     0.488789
# capital-gain                           0.252757
# education-num                          0.224867
# capital-loss                           0.024827
# hours-per-week                         0.008297
# age                                    0.000462

# %%
dtc_feature_importances = feature_importances[feature_importances['importances'] > 0].index
dtc_feature_importances
# Out:
# Index(['marital-status_ Married-civ-spouse', 'capital-gain', 'education-num',
#        'capital-loss', 'hours-per-week', 'age'],
#       dtype='object')

# %% [markdown]
# # 랜덤 포레스트로 분석하기

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
rfc = RandomForestClassifier(n_estimators=200, max_depth=4, n_jobs=10, random_state=10)
rfc.fit(X_train, y_train)
pred = rfc.predict(X_test)
print(classification_report(y_test, pred))

feature_importances = pd.DataFrame(rfc.feature_importances_, index=rfc.feature_names_in_, columns=['importances'])
feature_importances = feature_importances.sort_values(by='importances', ascending=False)
feature_importances[feature_importances['importances'] > 0.01]
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.89     11706
#            1       0.92      0.28      0.43      3990
#
#     accuracy                           0.81     15696
#    macro avg       0.86      0.64      0.66     15696
# weighted avg       0.83      0.81      0.77     15696
#                                     importances
# marital-status_ Married-civ-spouse     0.217282
# capital-gain                           0.164975
# education-num                          0.109109
# marital-status_ Never-married          0.087167
# age                                    0.065940
# hours-per-week                         0.042754
# relationship_ Not-in-family            0.042214
# relationship_ Own-child                0.041527
# occupation_ Exec-managerial            0.033154
# sex_ Male                              0.033119
# capital-loss                           0.032687
# occupation_ Prof-specialty             0.019104
# education_ Bachelors                   0.018129
# relationship_ Unmarried                0.014262
# education_ Masters                     0.012962
# education_ Prof-school                 0.010992
# occupation_ Other-service              0.010023

# %%
rfc_feature_importances = feature_importances[feature_importances['importances'] > 0.01].index
rfc_feature_importances
# Out:
# Index(['marital-status_ Married-civ-spouse', 'capital-gain', 'education-num',
#        'marital-status_ Never-married', 'age', 'hours-per-week',
#        'relationship_ Not-in-family', 'relationship_ Own-child',
#        'occupation_ Exec-managerial', 'sex_ Male', 'capital-loss',
#        'occupation_ Prof-specialty', 'education_ Bachelors',
#        'relationship_ Unmarried', 'education_ Masters',
#        'education_ Prof-school', 'occupation_ Other-service'],
#       dtype='object')

# %% [markdown]
# # XGBoost로 컬럼 중요도 출력

# %%
# !pip install xgboost lightgbm catboost
# Out:
# Requirement already satisfied: xgboost in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (2.1.4)
# Requirement already satisfied: lightgbm in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (4.6.0)
# Requirement already satisfied: catboost in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (1.2.8)
# Requirement already satisfied: numpy in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from xgboost) (2.0.2)
# Requirement already satisfied: scipy in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from xgboost) (1.13.1)
# Requirement already satisfied: graphviz in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from catboost) (3.9.4)
# Requirement already satisfied: pandas>=0.24 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from catboost) (2.3.2)
# Requirement already satisfied: plotly in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from catboost) (6.4.0)
# Requirement already satisfied: six in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib->catboost) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from matplotlib->catboost) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from plotly->catboost) (2.11.0)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report

# %%
xgb = RandomForestClassifier(n_estimators=200, max_depth=4, n_jobs=10, random_state=10)
xgb.fit(X_train, y_train)
pred = xgb.predict(X_test)
print(classification_report(y_test, pred))

feature_importances = pd.DataFrame(xgb.feature_importances_, index=xgb.feature_names_in_, columns=['importances'])
feature_importances = feature_importances.sort_values(by='importances', ascending=False)
feature_importances[feature_importances['importances'] > 0.01]
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.89     11706
#            1       0.92      0.28      0.43      3990
#
#     accuracy                           0.81     15696
#    macro avg       0.86      0.64      0.66     15696
# weighted avg       0.83      0.81      0.77     15696
#                                     importances
# marital-status_ Married-civ-spouse     0.217282
# capital-gain                           0.164975
# education-num                          0.109109
# marital-status_ Never-married          0.087167
# age                                    0.065940
# hours-per-week                         0.042754
# relationship_ Not-in-family            0.042214
# relationship_ Own-child                0.041527
# occupation_ Exec-managerial            0.033154
# sex_ Male                              0.033119
# capital-loss                           0.032687
# occupation_ Prof-specialty             0.019104
# education_ Bachelors                   0.018129
# relationship_ Unmarried                0.014262
# education_ Masters                     0.012962
# education_ Prof-school                 0.010992
# occupation_ Other-service              0.010023

# %%
xgb_feature_importances = feature_importances[feature_importances['importances'] > 0.01].index
xgb_feature_importances
# Out:
# Index(['marital-status_ Married-civ-spouse', 'capital-gain', 'education-num',
#        'marital-status_ Never-married', 'age', 'hours-per-week',
#        'relationship_ Not-in-family', 'relationship_ Own-child',
#        'occupation_ Exec-managerial', 'sex_ Male', 'capital-loss',
#        'occupation_ Prof-specialty', 'education_ Bachelors',
#        'relationship_ Unmarried', 'education_ Masters',
#        'education_ Prof-school', 'occupation_ Other-service'],
#       dtype='object')

# %%
important_cols = list(dtc_feature_importances) + list(rfc_feature_importances) + list(xgb_feature_importances)
important_cols
# Out:
# ['marital-status_ Married-civ-spouse',
#  'capital-gain',
#  'education-num',
#  'capital-loss',
#  'hours-per-week',
#  'age',
#  'marital-status_ Married-civ-spouse',
#  'capital-gain',
#  'education-num',
#  'marital-status_ Never-married',
#  'age',
#  'hours-per-week',
#  'relationship_ Not-in-family',
#  'relationship_ Own-child',
#  'occupation_ Exec-managerial',
#  'sex_ Male',
#  'capital-loss',
#  'occupation_ Prof-specialty',
#  'education_ Bachelors',
#  'relationship_ Unmarried',
#  'education_ Masters',
#  'education_ Prof-school',
#  'occupation_ Other-service',
#  'marital-status_ Married-civ-spouse',
#  'capital-gain',
#  'education-num',
#  'marital-status_ Never-married',
#  'age',
#  'hours-per-week',
#  'relationship_ Not-in-family',
#  'relationship_ Own-child',
#  'occupation_ Exec-managerial',
#  'sex_ Male',
#  'capital-loss',
#  'occupation_ Prof-specialty',
#  'education_ Bachelors',
#  'relationship_ Unmarried',
#  'education_ Masters',
#  'education_ Prof-school',
#  'occupation_ Other-service']

# %%
important_cols = set(important_cols)
important_cols
# Out:
# {'age',
#  'capital-gain',
#  'capital-loss',
#  'education-num',
#  'education_ Bachelors',
#  'education_ Masters',
#  'education_ Prof-school',
#  'hours-per-week',
#  'marital-status_ Married-civ-spouse',
#  'marital-status_ Never-married',
#  'occupation_ Exec-managerial',
#  'occupation_ Other-service',
#  'occupation_ Prof-specialty',
#  'relationship_ Not-in-family',
#  'relationship_ Own-child',
#  'relationship_ Unmarried',
#  'sex_ Male'}

# %%
important_cols = ['age', 'capital-gain', 'capital-loss', 'education-num',
                  'hours-per-week', 'marital-status', 'native-country', 
                  'occupation', 'sex']

# %%
len(important_cols)
# Out:
# 9

# %%
final_df = data2[important_cols]
final_df
# Out:
#        age  capital-gain  capital-loss  education-num  hours-per-week  \
# 0       25             0             0              7              40
# 1       38             0             0              9              50
# 2       28             0             0             12              40
# 3       44          7688             0             10              40
# 4       18             0             0             10              30
# ...    ...           ...           ...            ...             ...
# 48837   27             0             0             12              38
# 48838   40             0             0              9              40
# 48839   58             0             0              9              40
# 48840   22             0             0              9              20
# 48841   52         15024             0              9              40
#
#             marital-status  native-country          occupation      sex
# 0            Never-married   United-States   Machine-op-inspct     Male
# 1       Married-civ-spouse   United-States     Farming-fishing     Male
# 2       Married-civ-spouse   United-States     Protective-serv     Male
# 3       Married-civ-spouse   United-States   Machine-op-inspct     Male
# 4            Never-married   United-States                 NaN   Female
# ...                    ...             ...                 ...      ...
# 48837   Married-civ-spouse   United-States        Tech-support   Female
# 48838   Married-civ-spouse   United-States   Machine-op-inspct     Male
# 48839              Widowed   United-States        Adm-clerical   Female
# 48840        Never-married   United-States        Adm-clerical     Male
# 48841   Married-civ-spouse   United-States     Exec-managerial   Female
#
# [48842 rows x 9 columns]

# %%
X2 = data[important_cols]
y2 = data['class']

# %%
X2
# Out:
#        age  capital-gain  capital-loss  education-num  hours-per-week  \
# 0       25             0             0              7              40
# 1       38             0             0              9              50
# 2       28             0             0             12              40
# 3       44          7688             0             10              40
# 4       34             0             0              6              30
# ...    ...           ...           ...            ...             ...
# 39235   53             0             0             14              40
# 39236   22             0             0             10              40
# 39237   27             0             0             12              38
# 39238   58             0             0              9              40
# 39239   52         15024             0              9              40
#
#             marital-status  native-country          occupation      sex
# 0            Never-married   United-States   Machine-op-inspct     Male
# 1       Married-civ-spouse   United-States     Farming-fishing     Male
# 2       Married-civ-spouse   United-States     Protective-serv     Male
# 3       Married-civ-spouse   United-States   Machine-op-inspct     Male
# 4            Never-married   United-States       Other-service     Male
# ...                    ...             ...                 ...      ...
# 39235   Married-civ-spouse   United-States     Exec-managerial     Male
# 39236        Never-married   United-States     Protective-serv     Male
# 39237   Married-civ-spouse   United-States        Tech-support   Female
# 39238              Widowed   United-States        Adm-clerical   Female
# 39239   Married-civ-spouse   United-States     Exec-managerial   Female
#
# [39240 rows x 9 columns]

# %%
y2
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 39235    1
# 39236    0
# 39237    0
# 39238    0
# 39239    1
# Name: class, Length: 39240, dtype: int64

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.4, random_state=10, stratify=y)

# %%
X2_train, X2_test = ohe_transform(X2_train, X2_test)
X2_test
# Out:
#        marital-status_ Married-AF-spouse  marital-status_ Married-civ-spouse  \
# 22149                                0.0                                 0.0
# 21899                                0.0                                 1.0
# 12634                                0.0                                 1.0
# 1171                                 0.0                                 1.0
# 4839                                 0.0                                 0.0
# ...                                  ...                                 ...
# 25349                                0.0                                 1.0
# 34503                                0.0                                 0.0
# 15058                                0.0                                 1.0
# 28083                                0.0                                 1.0
# 38462                                0.0                                 0.0
#
#        marital-status_ Married-spouse-absent  marital-status_ Never-married  \
# 22149                                    0.0                            1.0
# 21899                                    0.0                            0.0
# 12634                                    0.0                            0.0
# 1171                                     0.0                            0.0
# 4839                                     0.0                            1.0
# ...                                      ...                            ...
# 25349                                    0.0                            0.0
# 34503                                    0.0                            0.0
# 15058                                    0.0                            0.0
# 28083                                    0.0                            0.0
# 38462                                    0.0                            1.0
#
#        marital-status_ Separated  marital-status_ Widowed  \
# 22149                        0.0                      0.0
# 21899                        0.0                      0.0
# 12634                        0.0                      0.0
# 1171                         0.0                      0.0
# 4839                         0.0                      0.0
# ...                          ...                      ...
# 25349                        0.0                      0.0
# 34503                        0.0                      1.0
# 15058                        0.0                      0.0
# 28083                        0.0                      0.0
# 38462                        0.0                      0.0
#
#        native-country_ Canada  native-country_ China  \
# 22149                     0.0                    0.0
# 21899                     0.0                    0.0
# 12634                     0.0                    0.0
# 1171                      0.0                    0.0
# 4839                      0.0                    0.0
# ...                       ...                    ...
# 25349                     0.0                    0.0
# 34503                     0.0                    0.0
# 15058                     0.0                    0.0
# 28083                     0.0                    0.0
# 38462                     0.0                    0.0
#
#        native-country_ Columbia  native-country_ Cuba  ...  \
# 22149                       0.0                   0.0  ...
# 21899                       0.0                   0.0  ...
# 12634                       0.0                   0.0  ...
# 1171                        0.0                   0.0  ...
# 4839                        0.0                   0.0  ...
# ...                         ...                   ...  ...
# 25349                       0.0                   0.0  ...
# 34503                       0.0                   0.0  ...
# 15058                       0.0                   0.0  ...
# 28083                       0.0                   0.0  ...
# 38462                       0.0                   0.0  ...
#
#        occupation_ Protective-serv  occupation_ Sales  \
# 22149                          0.0                0.0
# 21899                          0.0                0.0
# 12634                          0.0                0.0
# 1171                           0.0                0.0
# 4839                           0.0                1.0
# ...                            ...                ...
# 25349                          0.0                0.0
# 34503                          0.0                0.0
# 15058                          0.0                0.0
# 28083                          0.0                0.0
# 38462                          0.0                0.0
#
#        occupation_ Tech-support  occupation_ Transport-moving  sex_ Male  age  \
# 22149                       0.0                           0.0        1.0   26
# 21899                       0.0                           0.0        1.0   33
# 12634                       0.0                           1.0        1.0   41
# 1171                        0.0                           0.0        1.0   42
# 4839                        0.0                           0.0        1.0   24
# ...                         ...                           ...        ...  ...
# 25349                       0.0                           0.0        1.0   50
# 34503                       0.0                           0.0        1.0   64
# 15058                       0.0                           1.0        1.0   35
# 28083                       0.0                           0.0        1.0   27
# 38462                       0.0                           0.0        0.0   27
#
#        capital-gain  capital-loss  education-num  hours-per-week
# 22149             0             0              9              40
# 21899             0             0             16              40
# 12634             0             0             10              50
# 1171              0             0             10              70
# 4839              0             0              5              48
# ...             ...           ...            ...             ...
# 25349             0             0             15              40
# 34503             0             0             16              80
# 15058             0             0              9              50
# 28083             0             0              6              60
# 38462             0             0              9              50
#
# [15696 rows x 65 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %%
dtc = DecisionTreeClassifier(max_depth=4, random_state=10)
dtc.fit(X2_train, y2_train)
pred2 = dtc.predict(X2_test)
print(classification_report(y2_test, pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89     11706
#            1       0.75      0.51      0.61      3990
#
#     accuracy                           0.83     15696
#    macro avg       0.80      0.73      0.75     15696
# weighted avg       0.83      0.83      0.82     15696
