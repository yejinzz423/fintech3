# %% [markdown]
# <h1>주피터 노트북 사용법</h1>
# <ul>
#     <li>코딩모드</li>
#     <li>메모모드</li>
# </ul>

# %% [markdown]
# # \#은 h1 태그
# ## \##은 h2 태그
# ### \###은 h3 태그
# #### \####은 h4 태그

# %% [markdown]
# # ul은 \* 로 표시, 하위 항목은 들여쓰기 후 *
# * 목록
#   * 세부목록1
#   * 세부목록2
#   * 세부목록3

# %% [markdown]
# # 글시를 굵게 만들기 \**내용\**
# 글씨를 **굵게** 만들어 보아요.
# # 이텔릭체(기울이기) \*내용\*
# 글씨를 *기울여* 보아요.

# %% [markdown]
# # 링크걸기 \[링크이름\]\(링크주소\)
# [네이버링크](http://www.naver.com)

# %% [markdown]
# # 이미지 넣기 \!\[이미지설명\]\(이미지주소\)
# ![루피](https://image.msscdn.net/thumbnails/images/goods_img/20220314/2414773/2414773_34_big.jpg?w=1200)

# %% [markdown]
# ![car1.jpg](attachment:car1.jpg)

# %% [markdown]
# ![%EA%B3%A0%EC%96%91%EC%9D%B4.jpg](attachment:%EA%B3%A0%EC%96%91%EC%9D%B4.jpg)

# %% [markdown]
# # 수식넣기 \\$\\$수식코드 \\$\\$
# $${1 \over 2}$$
# ${1 \over 2}$

# %% [markdown]
# # 표 만들기 \|값\|의미\|기본값\| \|---\|---\|---\|
#
# |값|의미|기본값|
# |---|:---:|---:|
# |str|문자형 데이터 타입|str|
# |int|정수형 데이터 타입|0|
# |float|실수형 데이터 타입|3.14|

# %%
1+1

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
print(a+b)
# Out:
# 30

# %%
a
# Out:
# 10

# %%
b=20

# %%
c=30
