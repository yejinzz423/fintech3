# %% [markdown]
# 1. 키워드 입력
# 2. naver api에서 뉴스 수집
# 3. gemini로 뉴스 수집결과 요약해서 출력하기

# %%
# !pip install --upgrade google-genai
# !pip install gradio requests pandas python-dotenv google-genai
# Out:
# Collecting google-genai
#   Downloading google_genai-1.53.0-py3-none-any.whl.metadata (47 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-genai) (4.12.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-auth[requests]<3.0.0,>=2.14.1->google-genai) (2.43.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-genai) (2.12.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-genai) (2.32.5)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai)
#   Downloading websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Downloading google_genai-1.53.0-py3-none-any.whl (262 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (181 kB)
# Installing collected packages: websockets, tenacity, google-genai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [google-genai] [google-genai]
# Successfully installed google-genai-1.53.0 tenacity-9.1.2 websockets-15.0.1
# Requirement already satisfied: gradio in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (6.0.2)
# Requirement already satisfied: requests in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (2.32.5)
# Requirement already satisfied: pandas in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: python-dotenv in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: google-genai in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (1.53.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (4.12.0)
# Requirement already satisfied: brotli>=1.1.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (0.124.0)
# Requirement already satisfied: ffmpy in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.0.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (2.0.1)
# Requirement already satisfied: groovy~=0.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (2.2.6)
# Requirement already satisfied: orjson~=3.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (3.11.5)
# Requirement already satisfied: packaging in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (25.0)
# Requirement already satisfied: pillow<13.0,>=8.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (12.0.0)
# Requirement already satisfied: pydantic<=2.12.4,>=2.11.10 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (2.12.4)
# Requirement already satisfied: pydub in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from gradio-client==2.0.1->gradio) (2025.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from requests) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from requests) (2.6.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-auth[requests]<3.0.0,>=2.14.1->google-genai) (2.43.0)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Requirement already satisfied: six>=1.5 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/user/miniforge3/envs/hug/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
import os
import re
import html
import requests
import pandas as pd
import gradio as gr
from dotenv import load_dotenv
from google import genai

# -----------------------------
# 1) 환경변수 로드 (.env_gemini)
# -----------------------------
load_dotenv("./.env_gemini")

USER_ID = os.getenv("user_id")
USER_SECRET = os.getenv("user_secret")
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# -----------------------------
# 2) 텍스트 정제 함수
# -----------------------------
def text_clean(text: str) -> str:
    if text is None:
        return ""
    # HTML 태그 제거
    text = re.sub(r"<.*?>", "", text)
    # HTML 엔티티(&quot; 등) 복원
    text = html.unescape(text)
    return text.strip()

# -----------------------------
# 3) 네이버 뉴스 수집 함수
# -----------------------------
def fetch_naver_news(keyword: str,
                     display: int = 50,
                     max_pages: int = 2) -> pd.DataFrame:
    """
    keyword로 네이버 뉴스 검색 후 DataFrame 반환
    - display: 페이지당 결과 수 (최대 100)
    - max_pages: 가져올 최대 페이지 수
    """
    if not USER_ID or not USER_SECRET:
        raise RuntimeError("user_id / user_secret 환경변수가 설정되어 있지 않습니다.")

    url = "https://openapi.naver.com/v1/search/news"
    headers = {
        "X-Naver-Client-Id": USER_ID,
        "X-Naver-Client-Secret": USER_SECRET,
    }

    all_items = []

    # 1페이지 먼저 요청해서 total 확인
    payload = dict(query=keyword, display=display, start=1, sort="date")
    r = requests.get(url, params=payload, headers=headers)
    if r.status_code != 200:
        raise RuntimeError(f"네이버 API 오류: {r.status_code}, {r.text}")

    response = r.json()
    total = response.get("total", 0)
    if total == 0:
        return pd.DataFrame()

    total_pages = total // display + 1
    total_pages = min(total_pages, max_pages)

    all_items.extend(response.get("items", []))

    for page in range(2, total_pages + 1):
        start = (page - 1) * display + 1
        if start > 1000:  # 네이버 뉴스 API start 최대 1000
            break

        payload = dict(query=keyword, display=display, start=start, sort="date")
        r = requests.get(url, params=payload, headers=headers)
        if r.status_code != 200:
            print(f"[경고] {page}페이지 요청 실패: {r.status_code}")
            break

        resp = r.json()
        items = resp.get("items", [])
        if not items:
            break
        all_items.extend(items)

    result = {}
    for item in all_items:
        for key, value in item.items():
            if key in ["title", "description"]:
                result.setdefault(key, []).append(text_clean(value))
            else:
                result.setdefault(key, []).append(value)

    df = pd.DataFrame(result)
    return df

# -----------------------------
# 4) Gemini 요약 함수
# -----------------------------
def summarize_with_gemini(df: pd.DataFrame, keyword: str) -> str:
    if GEMINI_API_KEY is None:
        raise RuntimeError("GEMINI_API_KEY 환경변수가 설정되어 있지 않습니다.")

    client = genai.Client(api_key=GEMINI_API_KEY)

    if df.empty:
        return f"'{keyword}' 키워드로 수집된 뉴스가 없습니다."

    # 너무 길어지지 않도록 상위 20개만 사용
    df_use = df.head(20)

    news_lines = []
    for i, row in df_use.iterrows():
        title = row.get("title", "")
        desc = row.get("description", "")
        link = row.get("link", "")
        line = f"{i+1}. 제목: {title}\n   요약: {desc}\n   링크: {link}"
        news_lines.append(line)

    news_text = "\n\n".join(news_lines)

    prompt = f"""
다음은 '{keyword}' 키워드로 수집한 네이버 뉴스 목록입니다.

{news_text}

위 기사들을 바탕으로 다음 내용을 한국어로 정리해줘.

1) 전체 뉴스를 5~7줄 정도로 핵심만 요약
2) 주요 이슈/논점이 무엇인지 정리
3) 전반적인 분위기(긍정/부정/중립)를 한 줄로 평가
4) 추가로 눈에 띄는 서브 이슈가 있다면 2~3개 정도 bullet로 정리
5) 수집된 기사와 키워드의 주가를 분석해서 향후 주가에 미칠 영향 알려줘
"""

    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text

# -----------------------------
# 5) Gradio용 파이프라인 함수
# -----------------------------
def run_pipeline(keyword: str,
                 max_pages: int = 2,
                 display: int = 50):
    keyword = keyword.strip()
    if not keyword:
        return "키워드를 입력하세요.", pd.DataFrame()

    try:
        df = fetch_naver_news(keyword, display=display, max_pages=max_pages)
    except Exception as e:
        return f"네이버 뉴스 수집 중 오류 발생:\n{e}", pd.DataFrame()

    if df.empty:
        return f"'{keyword}' 키워드로 뉴스가 없습니다.", pd.DataFrame()

    try:
        summary = summarize_with_gemini(df, keyword)
    except Exception as e:
        return f"Gemini 요약 중 오류 발생:\n{e}", df[["title", "link"]]

    # 프리뷰용으로 제목+링크만 보여줌
    preview_df = df[["title", "link"]].head(50)

    return summary, preview_df

# -----------------------------
# 6) Gradio 인터페이스 정의
# -----------------------------
with gr.Blocks(title="네이버 뉴스 + Gemini 요약") as demo:
    gr.Markdown("## 🔍 키워드 기반 네이버 뉴스 요약 서비스\n\n"
                "키워드를 입력하면 네이버 뉴스에서 기사를 가져와서 Gemini로 요약해줍니다.")

    with gr.Row():
        keyword_input = gr.Textbox(
            label="검색 키워드",
            placeholder="예) 핀테크, 인공지능, 비트코인 ..."
        )
    with gr.Row():
        max_pages_input = gr.Slider(
            minimum=1,
            maximum=5,
            value=2,
            step=1,
            label="가져올 페이지 수 (페이지당 display개)"
        )
        display_input = gr.Slider(
            minimum=10,
            maximum=100,
            value=50,
            step=10,
            label="페이지당 기사 수 (display)"
        )

    run_button = gr.Button("뉴스 수집 & 요약 실행")

    summary_output = gr.Markdown(label="Gemini 요약 결과")
    table_output = gr.Dataframe(label="수집된 뉴스 (제목 + 링크)")

    run_button.click(
        fn=run_pipeline,
        inputs=[keyword_input, max_pages_input, display_input],
        outputs=[summary_output, table_output]
    )

# -----------------------------
# 7) 실행
# -----------------------------
if __name__ == "__main__":
    demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
